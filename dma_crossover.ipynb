# %% [markdown]
# <a href="https://colab.research.google.com/github/JenieJohn/jc/blob/master/dma_crossover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=yf.download('^GDAXI', start='2019-01-01')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker            ^GDAXI        ^GDAXI        ^GDAXI        ^GDAXI    ^GDAXI
# Date
# 2019-01-02  10580.190430  10612.719727  10386.969727  10477.769531  79626700
# 2019-01-03  10416.660156  10538.660156  10400.110352  10467.110352  84733800
# 2019-01-04  10767.690430  10786.339844  10483.900391  10533.940430  95339500
# 2019-01-07  10747.809570  10814.469727  10681.269531  10814.389648  71151400
# 2019-01-08  10803.980469  10910.709961  10745.030273  10750.190430  93672200
# ...                  ...           ...           ...           ...       ...
# 2025-05-21  24122.400391  24152.240234  23871.470703  23966.419922  58543400
# 2025-05-22  23999.169922  24040.210938  23843.070312  24017.060547  56102000
# 2025-05-23  23629.580078  24149.080078  23274.849609  24026.689453  94245400
# 2025-05-26  24027.650391  24050.599609  23932.039062  24009.099609  37001300
# 2025-05-27  24226.490234  24300.970703  24027.750000  24054.160156         0
#
# [1627 rows x 5 columns]

# %%
df['MA50'] = df['Close'].rolling(50).mean()
df['MA200'] = df['Close'].rolling(200).mean()

# %%
df
# Out:
# Price              Close          High           Low          Open    Volume  \
# Ticker            ^GDAXI        ^GDAXI        ^GDAXI        ^GDAXI    ^GDAXI
# Date
# 2019-01-02  10580.190430  10612.719727  10386.969727  10477.769531  79626700
# 2019-01-03  10416.660156  10538.660156  10400.110352  10467.110352  84733800
# 2019-01-04  10767.690430  10786.339844  10483.900391  10533.940430  95339500
# 2019-01-07  10747.809570  10814.469727  10681.269531  10814.389648  71151400
# 2019-01-08  10803.980469  10910.709961  10745.030273  10750.190430  93672200
# ...                  ...           ...           ...           ...       ...
# 2025-05-21  24122.400391  24152.240234  23871.470703  23966.419922  58543400
# 2025-05-22  23999.169922  24040.210938  23843.070312  24017.060547  56102000
# 2025-05-23  23629.580078  24149.080078  23274.849609  24026.689453  94245400
# 2025-05-26  24027.650391  24050.599609  23932.039062  24009.099609  37001300
# 2025-05-27  24226.490234  24300.970703  24027.750000  24054.160156         0
#
# Price               MA50         MA200
# Ticker
# Date
# 2019-01-02           NaN           NaN
# 2019-01-03           NaN           NaN
# 2019-01-04           NaN           NaN
# 2019-01-07           NaN           NaN
# 2019-01-08           NaN           NaN
# ...                  ...           ...
# 2025-05-21  22447.735547  20549.040996
# 2025-05-22  22475.299961  20582.341846
# 2025-05-23  22501.316172  20613.718145
# 2025-05-26  22528.340977  20645.780645
# 2025-05-27  22561.527969  20678.511094
#
# [1627 rows x 7 columns]

# %%
df = dfdropna()

# %%
df = df[['Close', 'MA50', 'MA200']]

# %%
df
# Out:
# Price              Close          High           Low          Open    Volume  \
# Ticker            ^GDAXI        ^GDAXI        ^GDAXI        ^GDAXI    ^GDAXI
# Date
# 2019-01-02  10580.190430  10612.719727  10386.969727  10477.769531  79626700
# 2019-01-03  10416.660156  10538.660156  10400.110352  10467.110352  84733800
# 2019-01-04  10767.690430  10786.339844  10483.900391  10533.940430  95339500
# 2019-01-07  10747.809570  10814.469727  10681.269531  10814.389648  71151400
# 2019-01-08  10803.980469  10910.709961  10745.030273  10750.190430  93672200
# ...                  ...           ...           ...           ...       ...
# 2025-05-21  24122.400391  24152.240234  23871.470703  23966.419922  58543400
# 2025-05-22  23999.169922  24040.210938  23843.070312  24017.060547  56102000
# 2025-05-23  23629.580078  24149.080078  23274.849609  24026.689453  94245400
# 2025-05-26  24027.650391  24050.599609  23932.039062  24009.099609  37001300
# 2025-05-27  24226.490234  24300.970703  24027.750000  24054.160156         0
#
# Price               MA50         MA200
# Ticker
# Date
# 2019-01-02           NaN           NaN
# 2019-01-03           NaN           NaN
# 2019-01-04           NaN           NaN
# 2019-01-07           NaN           NaN
# 2019-01-08           NaN           NaN
# ...                  ...           ...
# 2025-05-21  22447.735547  20549.040996
# 2025-05-22  22475.299961  20582.341846
# 2025-05-23  22501.316172  20613.718145
# 2025-05-26  22528.340977  20645.780645
# 2025-05-27  22561.527969  20678.511094
#
# [1627 rows x 7 columns]

# %%
Buy = []
Sell = []
for i in range(len(df)):
  if df.MA50.iloc[i] > df.MA200.iloc[i] \
  and df.MA50.iloc[i-1] < df.MA200.iloc[i-1]:
      Buy.append(i)
  elif df.MA50.iloc[i] < df.MA200.iloc[i] \
  and df.MA50.iloc[i-1] > df.MA200.iloc[i-1]:
      Sell.append(i)

# %%
Buy
# Out:
# [392, 1003, 1268]

# %%
Sell
# Out:
# [306, 793, 1217]

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Close'], label= 'Asset price', c='blue', alpha= 0.5)
plt.plot(df['MA50'], label= 'MA50', c='k', alpha = 0.9)
plt.plot(df['MA200'], label= 'MA200', c='magenta', alpha = 0.9)
plt.scatter(df.iloc[Buy].index,df.iloc[Buy]['Close'],marker='^', color='g', s=100)
plt.scatter(df.iloc[Sell].index,df.iloc[Sell]['Close'],marker='*', color='r', s=200)
plt.legend()
plt.show()
